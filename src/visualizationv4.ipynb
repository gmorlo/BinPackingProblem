# %%
from genetic_algorithm_bin_packing import genetic_algorithm_bin_packing
import matplotlib.pyplot as plt

item_list = [5, 7, 2, 9, 4, 3, 6, 8, 1, 10]
bin_capacity = 15

best, score, history = genetic_algorithm_bin_packing(
    item_list=item_list,
    bin_capacity=bin_capacity,
    population_size=10,
    max_generations=100,
    mutation_rate=0.3,
    patience=10,
    crossover_method='uniform'
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 7
#       4 item_list = [5, 7, 2, 9, 4, 3, 6, 8, 1, 10]
#       5 bin_capacity = 15
# ----> 7 best, score, history = genetic_algorithm_bin_packing(
#       8     item_list=item_list,
#       9     bin_capacity=bin_capacity,
#      10     population_size=10,
#      11     max_generations=100,
#      12     mutation_rate=0.3,
#      13     patience=10,
#      14     crossover_method='uniform'
#      15 )
#
# File c:\Users\gabry\OneDrive\Pulpit\Szkoła\MHE\BinPackingProblem\BinPackingProblem\src\genetic_algorithm_bin_packing.py:43, in genetic_algorithm_bin_packing(item_list, bin_capacity, population_size, max_generations, mutation_rate, patience, crossover_method, mutation_methods)
#      41     p1 = selected[i]
#      42     p2 = selected[(i + 1) % len(selected)]
# ---> 43     child = one_point_crossover(p1, p2) if crossover_method == 'one_point' else uniform_crossover(p1, p2)
#      44     offspring.append(child)
#      46 mutated = []
#
# File c:\Users\gabry\OneDrive\Pulpit\Szkoła\MHE\BinPackingProblem\BinPackingProblem\src\bin_packing_genetic_methods.py:28, in uniform_crossover(parent1, parent2)
#      26     child.append(parent1[i])
#      27     used.add(parent1[i])
# ---> 28 elif parent2[i] not in used:
#      29     child.append(parent2[i])
#      30     used.add(parent2[i])
#
# IndexError: list index out of range

# %%
print("Najlepsze rozwiązanie:", best)
print("Score:", score)

plt.plot(history)
plt.xlabel("Generacja")
plt.ylabel("Score")
plt.title("Postęp algorytmu genetycznego")
plt.grid(True)
plt.show()
# Out:
# Najlepsze rozwiązanie: [2, 1, 4, 8, 3, 10, 9, 8, 6, 5]
# Score: 4.4
